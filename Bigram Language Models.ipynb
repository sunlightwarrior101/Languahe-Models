# %%
def factorial(n):
  factorial_list = []
  if n > 0 and isinstance(n, int):
    result = 1
    for i in range(1, n+1):
      result = result * i
      # print('result', result)
  else:
    print('Enter valid input, a number greater than 0')
  return result



  print(i)

  # else:
  #   print('only accepts intergers')

# %%
class node():
  def __init__(self, value):
    self.value = value
    self.left = None
    self.right = None
    # name = self.name
    # address = self.address

  # def update(name, address):



class BinarySearchTree():

  def __init__(self):
    self.root = None


  def insert(self, value):
    new_node = node(value)
    if self.root is None:
      self.root = new_node

    else:
      current_node = self.root
      while True:
      if value < current_node.value:
        value = node.left

      else:
        value > self.right
        value = self.right







  def search(self, value):
    while self.value != node
      if value > self.root:
        node = node.left

      else:
        node = node.right

      return node

  def find_min(self, value):
    while self.value != node
      if self.value < node:
        return node
      else:
        none = node.left

        return node

  def find_max(self, value):
    while self.value != node
      if self.value > node:
        return node
      else:
        none = node.right

        return node
# Out:
#   File "<ipython-input-1-03b43d0ba8e5>", line 13
#     class BinarySearchTree:
#                            ^
# IndentationError: expected an indented block after function definition on line 9

# %%
class node():
  def self__init__(self, value):
    self.value = value
    self.left = None
    self.right = None
    name = self.name
    address = self.address

  # def update(name, address):



class BinarySearchTree():

  def __init__(self):
    self.root = None


  def insert(self, value):
      if value >= self.root:
       value = self.root

      elif:
        value < self.root
        if value < node.left:
          value = node.left

      else:
        value > self.right
        value = self.right







  def search(self, value):
    while self.value != node
      if value > self.root:
        node = node.left

      else:
        node = node.right

      return node

  def find_min(self, value):
    while self.value != node
      if self.value < node:
        return node
      else:
        none = node.left

        return node

  def find_max(self, value):
    while self.value != node
      if self.value > node:
        return node
      else:
        none = node.right

        return node
